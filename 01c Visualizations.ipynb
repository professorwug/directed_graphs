# %%
# default_exp 
from nbdev.showdoc import *
import numpy as np
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Visualizations for our Presentation

# %% [markdown]
# A really complicated graph which can't be visualized with nx.

# %%
from directed_graphs.datasets import SmallRandom, visualize_graph
dataset = SmallRandom(num_nodes=40, prob_edge=0.2)
data = dataset[0] # there is only graph in this dataset

# %%
visualize_graph(data)

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
A = torch.rand(3000,10000)
A = A.numpy()
A = A*100
Z = np.random.rand(3000,10000)
Z[Z < 0.6] = -1
A = Z*A

fig = plt.imshow(A,cmap='seismic')
fig.title("Big Data")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Untitled-2.ipynb Cell 6' in <cell line: 11>()
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#ch0000007untitled?line=8'>9</a> A = Z*A
#      <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#ch0000007untitled?line=9'>10</a> ax = plt.imshow(A,cmap='seismic')
# ---> <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#ch0000007untitled?line=10'>11</a> fig.title("Big Data")
#
# NameError: name 'fig' is not defined
